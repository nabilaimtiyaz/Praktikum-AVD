# %% [markdown]
# <a href="https://colab.research.google.com/github/nabilaimtiyaz/Praktikum-AVD/blob/main/CHECK_POINT_3_AVD_NabilaImtiyaz_Agustin_2409116011.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Praktikum Analitik dan Visualisasi Data
#
# **Nama**  : Nabila Imtiyaz Agustin
#
# **NIM**   : 2409116011
#
# **Kelas** : A 2024
#
# **Tema**  : Viewership Patterns: Analyze which leagues have the largest fan bases and where these are located geographically.

# %% [markdown]
# **1. Sumber Data**
#
# https://www.kaggle.com/datasets/bhadramohit/worlds-richest-sports-leagues-dataset

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("/content/drive/MyDrive/Praktikum AVD/top_expensive_leagues.csv")

df
# Out:
#     League ID     League Name  Country              Sport  Revenue (USD)  \
# 0        L001  Premier League  England           Football   5.275330e+09
# 1        L002         Serie A    India  American Football   7.088640e+09
# 2        L003             IPL  England  American Football   7.930520e+09
# 3        L004         La Liga    Spain  American Football   4.972890e+09
# 4        L005         Serie A    Italy         Basketball   6.265740e+09
# ..        ...             ...      ...                ...            ...
# 695      L696      Bundesliga   France           Football   2.280400e+09
# 696      L697         Ligue 1      USA            Cricket   6.945200e+08
# 697      L698  Premier League      USA           Football   5.251210e+09
# 698      L699             NBA  Germany  American Football   5.898850e+09
# 699      L700         La Liga    India           Football   2.865280e+09
#
#      Average Player Salary (USD)             Top Team  Total Teams  \
# ...

# %%
#analisis liga dengan basis penggemar terbesar
league_viewers = df.groupby("League Name")["Viewership"].sum().reset_index()
league_viewers = league_viewers.sort_values(by="Viewership", ascending=False).head(10)

plt.figure(figsize=(12, 6))
ax1 = sns.barplot(x="Viewership", y="League Name", data=league_viewers, color="skyblue")

for index, value in enumerate(league_viewers["Viewership"]):
    ax1.text(value + 0.01 * max(league_viewers["Viewership"]), index, f"{value:,}",
             va='center', fontsize=10)

plt.xlabel("Total Viewers")
plt.ylabel("League")
plt.title("Top 10 Leagues with the Largest Viewership")
plt.show()

# %%
#analisis 10 negara dengan viewership terbesar
top_countries = df.groupby("Country")["Viewership"].sum().reset_index()
top_countries = top_countries.sort_values(by="Viewership", ascending=False).head(10)
plt.figure(figsize=(12, 6))
ax2 = sns.barplot(x="Viewership", y="Country", data=top_countries, palette="pink")

for index, value in enumerate(top_countries["Viewership"]):
    ax2.text(value + 0.01 * max(top_countries["Viewership"]), index, f"{value:,}", va='center', fontsize=10)

plt.xlabel("Total Viewers")
plt.ylabel("Country")
plt.title("Top 10 Countries with the Largest Viewership")
plt.show()
# Out:
# <ipython-input-12-a98c4448eb3f>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax2 = sns.barplot(x="Viewership", y="Country", data=top_countries, palette="pink")

# %% [markdown]
# **2. Insight dan tindakan yang dapat diambil berdasarkan hasil visualisasi yang telah dibuat.**

# %% [markdown]
# Berdasarkan hasil visualisasi data yang telah dibuat diatas, maka ada beberapa insight dan tindakan yang dapat diambil sesuai dengan tujuan analisis.

# %% [markdown]
# 1. Insight
#
# *   Liga dengan Basis Penggemar Terbesar:
#
#
# Liga yang memiliki jumlah penonton terbanyak menunjukkan popularitas yang tinggi secara global.
# Jika beberapa liga memiliki gap yang besar dalam jumlah viewership dibandingkan liga lainnya, berarti ada dominan market leader di industri ini.
# Misalnya, jika Liga Inggris (EPL) jauh lebih unggul dibanding liga lain, ini menunjukkan bahwa strategi pemasaran dan daya tarik kompetisi mereka sangat kuat.
#
#
#
# *  Negara dengan Viewership Terbesar:
#
# Negara dengan jumlah penonton tertinggi menunjukkan pasar utama untuk penyiaran liga sepak bola.
# Jika ada beberapa negara yang memiliki angka viewership yang hampir sama, berarti ada potensi pengembangan yang luas bagi hak siar dan sponsorship di wilayah tersebut.
# Jika negara-negara berkembang memiliki angka viewership tinggi, ada potensi pertumbuhan bisnis di sana, misalnya melalui layanan streaming digital yang lebih murah.

# %% [markdown]
# 2. Tindakan yang dapat diambil
#
# *   Bagi Penyedia Hak Siar dan Media:
#
# Bagi penyedia hak siar dan media, dapat melakukan perluasan ke Negara dengan Potensi Tinggi. Jika ada negara berkembang dengan viewership yang terus meningkat, platform media harus segera berkembang ke sana.
#
#
#
# *   Bagi Perusahaan yang Beriklan di Sepak Bola:
#
# Targeting iklan yang lebih akurat, data yang dibuat ini bisa digunakan untuk memilih negara target utama untuk kampanye iklan yang berhubungan dengan sepak bola.
# Kemitraan dengan Klub Populer, jika data menunjukkan bahwa beberapa tim memiliki banyak penggemar di negara tertentu, maka brand dapat mensponsori klub tersebut untuk meningkatkan kesadaran di pasar tersebut.
